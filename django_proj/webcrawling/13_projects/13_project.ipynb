# %% [markdown]
# ### 라이브러리 가져오기

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### 뒤에 쓸 정규식 구현해놓기

# %%
import re
pattern = re.compile(r'[\t\r\n 적정가격]+')

# %% [markdown]
# ### URL 가져오기

# %%
url = 'https://www.paxnet.co.kr/stock/report/report?wlog_rpt=jm&menuCode=2222'

res = requests.get(url)
soup = BeautifulSoup(res.text, 'html.parser')

# %% [markdown]
# ### 종목이랑 URL 추출

# %%
#contents > div.cont-area > div.board-type > ul > li:nth-child(2) > div:nth-child(1) > strong > a

link_list = []

for i in soup.select('#contents div.cont-area div:nth-child(1) a'):
    #print(i['href'])
    print(i)
    if i['href'] != '#':
        link_list.append([i.text, i['href']])
    else:
        pass

link_list
# Out:
# <a href="http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&amp;abbrSymbol=005180">빙그레</a>
# <a href="http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&amp;abbrSymbol=378800">샤페론</a>
# <a href="http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&amp;abbrSymbol=290650">엘앤씨바이오</a>
# <a href="http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&amp;abbrSymbol=347850">디앤디파마텍</a>
# <a href="http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&amp;abbrSymbol=286940">롯데이노베이트</a>
# <a href="http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&amp;abbrSymbol=083650">비에이치아이</a>
# <a href="http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&amp;abbrSymbol=054450">텔레칩스</a>
# <a href="http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&amp;abbrSymbol=102120">어보브반도체</a>
# <a href="http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&amp;abbrSymbol=011790">SKC</a>
# <a href="http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&amp;abbrSymbol=389260">대명에너지</a>
# <a href="http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&amp;abbrSymbol=016250">SGC E&amp;C</a>
# <a href="http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&amp;abbrSymbol=402340">SK스퀘어</a>
# <a href="http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&amp;abbrSymbol=000660">SK하이닉스</a>
# <a href="http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&amp;abbrSymbol=204270">제이앤티씨</a>
# <a href="http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&amp;abbrSymbol=010780">아이에스동서</a>
# <a href="http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&amp;abbrSymbol=338220">뷰노</a>
# <a href="http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&amp;abbrSymbol=108490">로보티즈</a>
# <a href="http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&amp;abbrSymbol=097950">CJ제일제당</a>
# <a href="http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&amp;abbrSymbol=012330">현대모비스</a>
# <a href="http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&amp;abbrSymbol=263750">펄어비스</a>
# <a href="http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&amp;abbrSymbol=443670">에스피소프트</a>
# <a href="http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&amp;abbrSymbol=126340">비나텍</a>
# <a href="http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&amp;abbrSymbol=260970">에스앤디</a>
# <a href="http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&amp;abbrSymbol=282880">코윈테크</a>
# <a href="http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&amp;abbrSymbol=003690">코리안리</a>
# <a href="http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&amp;abbrSymbol=005380">현대차</a>
# <a href="http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&amp;abbrSymbol=043150">바텍</a>
# <a href="http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&amp;abbrSymbol=357780">솔브레인</a>
# <a href="http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&amp;abbrSymbol=002990">금호건설</a>
# <a href="http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&amp;abbrSymbol=097950">CJ제일제당</a>
# <a class="prev" href="#" onclick="linkPage(1);return false;">맨 처음 페이지</a>
# <a class="before" href="#" onclick="linkPage(1); return false;">[이전]</a>
# <a href="#">1</a>
# <a href="#" onclick="linkPage(2); return false;">2</a>
# <a href="#" onclick="linkPage(3); return false;">3</a>
# <a href="#" onclick="linkPage(4); return false;">4</a>
# <a href="#" onclick="linkPage(5); return false;">5</a>
# <a class="after" href="#" onclick="linkPage(6); return false;">[다음]</a>
# <a class="next" href="#" onclick="linkPage(767);return false;">맨 마지막 페이지</a>
# [['빙그레',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=005180'],
#  ['샤페론',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=378800'],
#  ['엘앤씨바이오',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=290650'],
#  ['디앤디파마텍',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=347850'],
#  ['롯데이노베이트',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=286940'],
#  ['비에이치아이',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=083650'],
#  ['텔레칩스',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=054450'],
#  ['어보브반도체',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=102120'],
#  ['SKC',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=011790'],
#  ['대명에너지',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=389260'],
#  ['SGC E&C',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=016250'],
#  ['SK스퀘어',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=402340'],
#  ['SK하이닉스',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=000660'],
#  ['제이앤티씨',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=204270'],
#  ['아이에스동서',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=010780'],
#  ['뷰노',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=338220'],
#  ['로보티즈',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=108490'],
#  ['CJ제일제당',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=097950'],
#  ['현대모비스',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=012330'],
#  ['펄어비스',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=263750'],
#  ['에스피소프트',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=443670'],
#  ['비나텍',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=126340'],
#  ['에스앤디',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=260970'],
#  ['코윈테크',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=282880'],
#  ['코리안리',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=003690'],
#  ['현대차',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=005380'],
#  ['바텍',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=043150'],
#  ['솔브레인',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=357780'],
#  ['금호건설',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=002990'],
#  ['CJ제일제당',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=097950']]

# %% [markdown]
# ### 제목 추출

# %%
#contents > div.cont-area > div.board-type > ul > li:nth-child(17) > div:nth-child(2) > p > a
title_list = []
for i in soup.select('#contents p a'):
    #print(i.text)
    title_list.append(pattern.sub(' ', i.text))

#title_list에 안 보이는 텍스트가 있는데 어차피 zip으로 묶을꺼라 괜찮아보임
#zip은 작은 숫자로 매핑

title_list
# Out:
# ['지주사 전환 및 자사주 소각 Comment',
#  '염증복합체 억제제 ？ 나노맵 원천기술 보유 기업 ',
#  '다 오는 터닝포인트 ',
#  'GLP-1 계열 비만 치료제의 라이징 스타 ',
#  '신규 사업 확대와 주주환원 책 극 으로 추진 중 ',
#  '설레는 마음으로 기다리는 2025 년',
#  '고객 다변화 기대되는 비메모리 반도체 토종 기업 ',
#  '국내 최고의 마이크로 컨트롤러 유닛 공급사 ',
#  '미국 NAPMP 보조금 1,400 억원 지급 대상 선 ',
#  '해상풍력, ESS 기대되는 25년',
#  '[NDR 후기] 곧 달라질 그림',
#  '자사주 소각 그리고 매입, 목표주 도 상향',
#  'NAND 경쟁 심화 예상',
#  '3Q24 Review: 신제품 출시 수혜 기대',
#  'NDR 후기] 대형 개발사업 시화 기대',
#  '미뤄졌을 뿐, 목표를 위해 나아갈 뿐',
#  'MIT 와 공동개발 뉴스 Comment',
#  '바이오 사업부 매각 관련 Comment',
#  'CEO Investor Day 후기',
#  '시연을 통해 얻은 성과',
#  '본 게임은 25년부터',
#  '3Q24 Review: 시장기대치 하회 MEA 판 개선에 주목',
#  '3Q24 Review: 여전한 실 의 K-Food 수혜',
#  '3Q24 Review: 전고체 배터리 장비 공급 예 ',
#  '제도 혼란, 재보험사의 장 뚜렷한 모멘텀',
#  '미 관세 Worst Case 고려해도 너무 싼 주 ',
#  '2025년 회복이 기대된다.',
#  '3Q24 Review: 컨센서스 하회',
#  '[NDR 후기] 리스크와 기회의 재 립 필요',
#  '바이오 사업 매각 News Comment',
#  '자세히보기',
#  '많이 본 투자전략',
#  '전문 강좌',
#  ' ',
#  ' ',
#  ' ',
#  ' ']

# %% [markdown]
# ### 투자사 추출

# %%
soup.select('#contents > div.cont-area > div.board-type div:nth-child(5)')
investment_list = []
for i in soup.select('#contents > div.cont-area > div.board-type div:nth-child(5)'):
    #print(i.text)
    if i.text != '제공출처':
        investment_list.append(i.text)
    else:
        pass


investment_list
# Out:
# ['메리츠증권',
#  '교보증권',
#  '한국IR협의회',
#  '한국IR협의회',
#  '한국IR협의회',
#  '메리츠증권',
#  '한국IR협의회',
#  '한국IR협의회',
#  '메리츠증권',
#  'SK증권',
#  'LS증권',
#  'SK증권',
#  '키움증권',
#  '유진투자증권',
#  'LS증권',
#  '키움증권',
#  '메리츠증권',
#  '키움증권',
#  'LS증권',
#  '키움증권',
#  'IBK투자증권',
#  '유진투자증권',
#  '유진투자증권',
#  '유진투자증권',
#  'SK증권',
#  'SK증권',
#  'LS증권',
#  'LS증권',
#  'LS증권',
#  '메리츠증권']

# %% [markdown]
# ### 작성일 추출

# %%
#contents > div.cont-area > div.board-type > ul > li:nth-child(20) > div:nth-child(6)
soup.select('#contents > div.cont-area > div.board-type div:nth-child(5)')
post_date = []
for i in soup.select('#contents > div.cont-area > div.board-type div:nth-child(6)'):
    #print(i.text)
    if i.text != '작성일':
        post_date.append(i.text)
    else:
        pass


post_date
# Out:
# ['2024.11.25',
#  '2024.11.25',
#  '2024.11.25',
#  '2024.11.25',
#  '2024.11.25',
#  '2024.11.22',
#  '2024.11.22',
#  '2024.11.22',
#  '2024.11.22',
#  '2024.11.22',
#  '2024.11.22',
#  '2024.11.22',
#  '2024.11.22',
#  '2024.11.21',
#  '2024.11.21',
#  '2024.11.21',
#  '2024.11.20',
#  '2024.11.20',
#  '2024.11.20',
#  '2024.11.20',
#  '2024.11.19',
#  '2024.11.19',
#  '2024.11.19',
#  '2024.11.19',
#  '2024.11.19',
#  '2024.11.19',
#  '2024.11.19',
#  '2024.11.19',
#  '2024.11.19',
#  '2024.11.19']

# %% [markdown]
# ### 적정 가격 추출

# %%
#contents > div.cont-area > div.board-type > ul > li:nth-child(2) > div:nth-child(3)
price_list = []
for i in soup.select('#contents div:nth-child(3)')[1:]:
    # 첫줄에 적정가격 header가 있어서 1이후부터 끝까지

    #여러 공백 문자가 있지만, 위에 정규식으로 처리
#     i.text.strip().replace('	','').replace(' ','').replace('''
#  ''','')
    print(pattern.sub('',i.text))
    price_list.append(pattern.sub('',i.text))

price_list
# Out:
# -원
# -원
# -원
# -원
# -원
# -원
# -원
# -원
# -원
# 18,000원
# -원
# 105,000원
# 210,000원
# 26,000원
# 30,000원
# 43000원
# -원
# -원
# 310,000원
# 57000원
# -원
# 50,000원
# -원
# 22,000원
# 9,500원
# 330,000원
# 30,000원
# 320,000원
# -원
# -원
# 많이본투자전략241115옵션만기후과매도반전의조건,그리고트럼프변동의상화■(상한)에스와이~범양건영~축~삼성전자5만원예고■(급등+상한)셀리드+CJ바이오[당일위츠250%]~축~상한,준상한大폭발~`그저먹기장세★어려운장종목추천★오리엔탈공■(9회1위(((수상)))제대로된황금대장주를담아라!■(11월대장)위츠(250%)범양건영(135%)★긴급★한달30%수익반3기종료,4기모집중(11월25일시작)★공지★한달목표+30%수익반4기모집★신규상장주★위츠대박수익(+94%,+73%)2회나눠익절
# ['-원',
#  '-원',
#  '-원',
#  '-원',
#  '-원',
#  '-원',
#  '-원',
#  '-원',
#  '-원',
#  '18,000원',
#  '-원',
#  '105,000원',
#  '210,000원',
#  '26,000원',
#  '30,000원',
#  '43000원',
#  '-원',
#  '-원',
#  '310,000원',
#  '57000원',
#  '-원',
#  '50,000원',
#  '-원',
#  '22,000원',
#  '9,500원',
#  '330,000원',
#  '30,000원',
#  '320,000원',
#  '-원',
#  '-원',
#  '많이본투자전략241115옵션만기후과매도반전의조건,그리고트럼프변동의상화■(상한)에스와이~범양건영~축~삼성전자5만원예고■(급등+상한)셀리드+CJ바이오[당일위츠250%]~축~상한,준상한大폭발~`그저먹기장세★어려운장종목추천★오리엔탈공■(9회1위(((수상)))제대로된황금대장주를담아라!■(11월대장)위츠(250%)범양건영(135%)★긴급★한달30%수익반3기종료,4기모집중(11월25일시작)★공지★한달목표+30%수익반4기모집★신규상장주★위츠대박수익(+94%,+73%)2회나눠익절']

# %% [markdown]
# ### 투자 포지셔닝 추출

# %%
color_class = ['line3 color-black',
          'line3 color-red',
          'line3 color-blue']

soup.findAll('div', class_ = color_class)

position_list = []
for i in soup.findAll('div', class_ = color_class):
    position_list.append(pattern.sub('',i.text))

position_list
# Out:
# ['-',
#  '-',
#  '매수',
#  '-',
#  '-',
#  '-',
#  '매수',
#  '-',
#  '-',
#  '매수',
#  '-',
#  '매수',
#  '매수',
#  '매수',
#  '매수',
#  '매수(유지)',
#  '매수',
#  '-',
#  '매수',
#  '매수',
#  '-',
#  '매수',
#  '-',
#  '매수',
#  '매수',
#  '매수',
#  '매수',
#  '매수',
#  '-',
#  '-']

# %% [markdown]
# ### 추출한거 다 합치기

# %%
#link_list 건들이기 싫어서 list 새로 만듦
final_list = []

for i,j,y,z, a,b in zip(link_list, title_list, investment_list, post_date, price_list, position_list):
    tmp_list = []
    tmp_list.append(i[0])
    tmp_list.append(i[1])
    tmp_list.append(j)
    tmp_list.append(y)
    tmp_list.append(z)    
    tmp_list.append(a)
    tmp_list.append(b)
    final_list.append(tmp_list)

final_list
#이러면 final_list에 6개 컬럼 들어감
#종목 | 세부링크 | 게시물 제목 | |투자사 | 작성일 | 투자 포지셔닝
# Out:
# [['빙그레',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=005180',
#   '지주사 전환 및 자사주 소각 Comment',
#   '메리츠증권',
#   '2024.11.25',
#   '-원',
#   '-'],
#  ['샤페론',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=378800',
#   '염증복합체 억제제 ？ 나노맵 원천기술 보유 기업 ',
#   '교보증권',
#   '2024.11.25',
#   '-원',
#   '-'],
#  ['엘앤씨바이오',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=290650',
#   '다 오는 터닝포인트 ',
#   '한국IR협의회',
#   '2024.11.25',
#   '-원',
#   '매수'],
#  ['디앤디파마텍',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=347850',
#   'GLP-1 계열 비만 치료제의 라이징 스타 ',
#   '한국IR협의회',
#   '2024.11.25',
#   '-원',
#   '-'],
#  ['롯데이노베이트',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=286940',
#   '신규 사업 확대와 주주환원 책 극 으로 추진 중 ',
#   '한국IR협의회',
#   '2024.11.25',
#   '-원',
#   '-'],
#  ['비에이치아이',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=083650',
#   '설레는 마음으로 기다리는 2025 년',
#   '메리츠증권',
#   '2024.11.22',
#   '-원',
#   '-'],
#  ['텔레칩스',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=054450',
#   '고객 다변화 기대되는 비메모리 반도체 토종 기업 ',
#   '한국IR협의회',
#   '2024.11.22',
#   '-원',
#   '매수'],
#  ['어보브반도체',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=102120',
#   '국내 최고의 마이크로 컨트롤러 유닛 공급사 ',
#   '한국IR협의회',
#   '2024.11.22',
#   '-원',
#   '-'],
#  ['SKC',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=011790',
#   '미국 NAPMP 보조금 1,400 억원 지급 대상 선 ',
#   '메리츠증권',
#   '2024.11.22',
#   '-원',
#   '-'],
#  ['대명에너지',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=389260',
#   '해상풍력, ESS 기대되는 25년',
#   'SK증권',
#   '2024.11.22',
#   '18,000원',
#   '매수'],
#  ['SGC E&C',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=016250',
#   '[NDR 후기] 곧 달라질 그림',
#   'LS증권',
#   '2024.11.22',
#   '-원',
#   '-'],
#  ['SK스퀘어',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=402340',
#   '자사주 소각 그리고 매입, 목표주 도 상향',
#   'SK증권',
#   '2024.11.22',
#   '105,000원',
#   '매수'],
#  ['SK하이닉스',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=000660',
#   'NAND 경쟁 심화 예상',
#   '키움증권',
#   '2024.11.22',
#   '210,000원',
#   '매수'],
#  ['제이앤티씨',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=204270',
#   '3Q24 Review: 신제품 출시 수혜 기대',
#   '유진투자증권',
#   '2024.11.21',
#   '26,000원',
#   '매수'],
#  ['아이에스동서',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=010780',
#   'NDR 후기] 대형 개발사업 시화 기대',
#   'LS증권',
#   '2024.11.21',
#   '30,000원',
#   '매수'],
#  ['뷰노',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=338220',
#   '미뤄졌을 뿐, 목표를 위해 나아갈 뿐',
#   '키움증권',
#   '2024.11.21',
#   '43000원',
#   '매수(유지)'],
#  ['로보티즈',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=108490',
#   'MIT 와 공동개발 뉴스 Comment',
#   '메리츠증권',
#   '2024.11.20',
#   '-원',
#   '매수'],
#  ['CJ제일제당',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=097950',
#   '바이오 사업부 매각 관련 Comment',
#   '키움증권',
#   '2024.11.20',
#   '-원',
#   '-'],
#  ['현대모비스',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=012330',
#   'CEO Investor Day 후기',
#   'LS증권',
#   '2024.11.20',
#   '310,000원',
#   '매수'],
#  ['펄어비스',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=263750',
#   '시연을 통해 얻은 성과',
#   '키움증권',
#   '2024.11.20',
#   '57000원',
#   '매수'],
#  ['에스피소프트',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=443670',
#   '본 게임은 25년부터',
#   'IBK투자증권',
#   '2024.11.19',
#   '-원',
#   '-'],
#  ['비나텍',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=126340',
#   '3Q24 Review: 시장기대치 하회 MEA 판 개선에 주목',
#   '유진투자증권',
#   '2024.11.19',
#   '50,000원',
#   '매수'],
#  ['에스앤디',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=260970',
#   '3Q24 Review: 여전한 실 의 K-Food 수혜',
#   '유진투자증권',
#   '2024.11.19',
#   '-원',
#   '-'],
#  ['코윈테크',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=282880',
#   '3Q24 Review: 전고체 배터리 장비 공급 예 ',
#   '유진투자증권',
#   '2024.11.19',
#   '22,000원',
#   '매수'],
#  ['코리안리',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=003690',
#   '제도 혼란, 재보험사의 장 뚜렷한 모멘텀',
#   'SK증권',
#   '2024.11.19',
#   '9,500원',
#   '매수'],
#  ['현대차',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=005380',
#   '미 관세 Worst Case 고려해도 너무 싼 주 ',
#   'SK증권',
#   '2024.11.19',
#   '330,000원',
#   '매수'],
#  ['바텍',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=043150',
#   '2025년 회복이 기대된다.',
#   'LS증권',
#   '2024.11.19',
#   '30,000원',
#   '매수'],
#  ['솔브레인',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=357780',
#   '3Q24 Review: 컨센서스 하회',
#   'LS증권',
#   '2024.11.19',
#   '320,000원',
#   '매수'],
#  ['금호건설',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=002990',
#   '[NDR 후기] 리스크와 기회의 재 립 필요',
#   'LS증권',
#   '2024.11.19',
#   '-원',
#   '-'],
#  ['CJ제일제당',
#   'http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&abbrSymbol=097950',
#   '바이오 사업 매각 News Comment',
#   '메리츠증권',
#   '2024.11.19',
#   '-원',
#   '-']]

# %% [markdown]
# ### csv 저장하기

# %%
#csv로 저장함

import pandas as pd

df = pd.DataFrame(final_list, columns = ['stock','url', 'title','investment', 'date', 'price', 'position'])
df

df.to_csv('13_project_stock.csv', index = False, encoding = 'cp949')

# %% [markdown]
# ### db 연결하기

# %%
# db 연결함
from db_config import config

print(config)
# Out:
# {'user': 'root', 'password': 'uos3103301!', 'host': 'localhost', 'database': 'my_db'}

# %% [markdown]
# ### 테이블 만들기(CREATE)

# %%
# query1.py 실행하기
# 이거 테이블 만드는 거임

# !python query1.py
# Out:
# 테이블 생성함

# %% [markdown]
# ### INSERT 치기

# %%
# query2.py 실행하기
# 여기는 데이터 밀어넣음
# !python query2.py
# Out:
# INSERT 완료

# %% [markdown]
# ### SELECT로 개수 보기

# %%
# 조회하고 DB연결 끊기
# !python query3.py
# Out:
# 해당 테이블에 30개 있습니다

# %% [markdown]
# # 그래프 그려보기(쟉업중)

# %%
df
# Out:
#       stock                                                url  \
# 0       빙그레  http://www.paxnet.co.kr/stock/analysis/main?wl...
# 1       샤페론  http://www.paxnet.co.kr/stock/analysis/main?wl...
# 2    엘앤씨바이오  http://www.paxnet.co.kr/stock/analysis/main?wl...
# 3    디앤디파마텍  http://www.paxnet.co.kr/stock/analysis/main?wl...
# 4   롯데이노베이트  http://www.paxnet.co.kr/stock/analysis/main?wl...
# 5    비에이치아이  http://www.paxnet.co.kr/stock/analysis/main?wl...
# 6      텔레칩스  http://www.paxnet.co.kr/stock/analysis/main?wl...
# 7    어보브반도체  http://www.paxnet.co.kr/stock/analysis/main?wl...
# 8       SKC  http://www.paxnet.co.kr/stock/analysis/main?wl...
# 9     대명에너지  http://www.paxnet.co.kr/stock/analysis/main?wl...
# 10  SGC E&C  http://www.paxnet.co.kr/stock/analysis/main?wl...
# 11    SK스퀘어  http://www.paxnet.co.kr/stock/analysis/main?wl...
# 12   SK하이닉스  http://www.paxnet.co.kr/stock/analysis/main?wl...
# 13    제이앤티씨  http://www.paxnet.co.kr/stock/analysis/main?wl...
# 14   아이에스동서  http://www.paxnet.co.kr/stock/analysis/main?wl...
# 15       뷰노  http://www.paxnet.co.kr/stock/analysis/main?wl...
# 16     로보티즈  http://www.paxnet.co.kr/stock/analysis/main?wl...
# 17   CJ제일제당  http://www.paxnet.co.kr/stock/analysis/main?wl...
# 18    현대모비스  http://www.paxnet.co.kr/stock/analysis/main?wl...
# 19     펄어비스  http://www.paxnet.co.kr/stock/analysis/main?wl...
# 20   에스피소프트  http://www.paxnet.co.kr/stock/analysis/main?wl...
# 21      비나텍  http://www.paxnet.co.kr/stock/analysis/main?wl...
# 22     에스앤디  http://www.paxnet.co.kr/stock/analysis/main?wl...
# 23     코윈테크  http://www.paxnet.co.kr/stock/analysis/main?wl...
# 24     코리안리  http://www.paxnet.co.kr/stock/analysis/main?wl...
# 25      현대차  http://www.paxnet.co.kr/stock/analysis/main?wl...
# 26       바텍  http://www.paxnet.co.kr/stock/analysis/main?wl...
# 27     솔브레인  http://www.paxnet.co.kr/stock/analysis/main?wl...
# 28     금호건설  http://www.paxnet.co.kr/stock/analysis/main?wl...
# 29   CJ제일제당  http://www.paxnet.co.kr/stock/analysis/main?wl...
#
#                                  title investment        date     price  \
# 0              지주사 전환 및 자사주 소각 Comment      메리츠증권  2024.11.25        -원
# 1          염증복합체 억제제 ？ 나노맵 원천기술 보유 기업        교보증권  2024.11.25        -원
# 2                          다 오는 터닝포인트     한국IR협의회  2024.11.25        -원
# 3             GLP-1 계열 비만 치료제의 라이징 스타     한국IR협의회  2024.11.25        -원
# 4          신규 사업 확대와 주주환원 책 극 으로 추진 중     한국IR협의회  2024.11.25        -원
# 5                 설레는 마음으로 기다리는 2025 년      메리츠증권  2024.11.22        -원
# 6          고객 다변화 기대되는 비메모리 반도체 토종 기업     한국IR협의회  2024.11.22        -원
# 7             국내 최고의 마이크로 컨트롤러 유닛 공급사     한국IR협의회  2024.11.22        -원
# 8       미국 NAPMP 보조금 1,400 억원 지급 대상 선       메리츠증권  2024.11.22        -원
# 9                   해상풍력, ESS 기대되는 25년       SK증권  2024.11.22   18,000원
# 10                   [NDR 후기] 곧 달라질 그림       LS증권  2024.11.22        -원
# 11             자사주 소각 그리고 매입, 목표주 도 상향       SK증권  2024.11.22  105,000원
# 12                       NAND 경쟁 심화 예상       키움증권  2024.11.22  210,000원
# 13           3Q24 Review: 신제품 출시 수혜 기대     유진투자증권  2024.11.21   26,000원
# 14               NDR 후기] 대형 개발사업 시화 기대       LS증권  2024.11.21   30,000원
# 15                미뤄졌을 뿐, 목표를 위해 나아갈 뿐       키움증권  2024.11.21    43000원
# 16               MIT 와 공동개발 뉴스 Comment      메리츠증권  2024.11.20        -원
# 17               바이오 사업부 매각 관련 Comment       키움증권  2024.11.20        -원
# 18                 CEO Investor Day 후기       LS증권  2024.11.20  310,000원
# 19                        시연을 통해 얻은 성과       키움증권  2024.11.20    57000원
# 20                         본 게임은 25년부터    IBK투자증권  2024.11.19        -원
# 21  3Q24 Review: 시장기대치 하회 MEA 판 개선에 주목     유진투자증권  2024.11.19   50,000원
# 22      3Q24 Review: 여전한 실 의 K-Food 수혜     유진투자증권  2024.11.19        -원
# 23       3Q24 Review: 전고체 배터리 장비 공급 예      유진투자증권  2024.11.19   22,000원
# 24              제도 혼란, 재보험사의 장 뚜렷한 모멘텀       SK증권  2024.11.19    9,500원
# 25        미 관세 Worst Case 고려해도 너무 싼 주        SK증권  2024.11.19  330,000원
# 26                     2025년 회복이 기대된다.       LS증권  2024.11.19   30,000원
# 27                3Q24 Review: 컨센서스 하회       LS증권  2024.11.19  320,000원
# 28            [NDR 후기] 리스크와 기회의 재 립 필요       LS증권  2024.11.19        -원
# 29              바이오 사업 매각 News Comment      메리츠증권  2024.11.19        -원
#
#    position
# 0         -
# 1         -
# 2        매수
# 3         -
# 4         -
# 5         -
# 6        매수
# 7         -
# 8         -
# 9        매수
# 10        -
# 11       매수
# 12       매수
# 13       매수
# 14       매수
# 15   매수(유지)
# 16       매수
# 17        -
# 18       매수
# 19       매수
# 20        -
# 21       매수
# 22        -
# 23       매수
# 24       매수
# 25       매수
# 26       매수
# 27       매수
# 28        -
# 29        -

# %%
import matplotlib
print(matplotlib.matplotlib_fname())
# Out:
# C:\Users\YJ\AppData\Local\Microsoft\Windows\Fonts\NotoSansKR-Regular.ttf
# C:\Users\YJ\AppData\Local\Microsoft\Windows\Fonts\NotoSansKR-ExtraLight.ttf
# C:\Users\YJ\AppData\Local\Microsoft\Windows\Fonts\NotoSansKR-ExtraBold.ttf
# C:\Users\YJ\AppData\Local\Microsoft\Windows\Fonts\NotoSansKR-Thin.ttf
# C:\Users\YJ\AppData\Local\Microsoft\Windows\Fonts\NotoSansKR-Bold.ttf
# C:\Users\YJ\AppData\Local\Microsoft\Windows\Fonts\NotoSansKR-Black.ttf
# C:\Users\YJ\AppData\Local\Microsoft\Windows\Fonts\NotoSansKR-Medium.ttf
# C:\Users\YJ\AppData\Local\Microsoft\Windows\Fonts\NotoSansKR-Light.ttf
# C:\Users\YJ\AppData\Local\Microsoft\Windows\Fonts\NotoSansKR-SemiBold.ttf

# %%
import matplotlib.font_manager as fm

#원하는 한글 글꼴 찾기
font_path = [i for i in fm.findSystemFonts(fontext='ttf') if 'NotoSansKR-Black' in i]
print(font_path[0])
font_prop = fm.FontProperties(fname = font_path)

print(font_prop)
# Out:
# C:\Users\YJ\AppData\Local\Microsoft\Windows\Fonts\NotoSansKR-Black.ttf
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[265], line 6
#       4 font_path = [i for i in fm.findSystemFonts(fontext='ttf') if 'NotoSansKR-Black' in i]
#       5 print(font_path[0])
# ----> 6 font_prop = fm.FontProperties(fname = font_path)
#       8 print(font_prop)
#
# File c:\Users\YJ\.conda\envs\django\Lib\site-packages\matplotlib\font_manager.py:611, in FontProperties.__init__(self, family, style, variant, weight, stretch, size, fname, math_fontfamily)
#     609 self.set_weight(weight)
#     610 self.set_stretch(stretch)
# --> 611 self.set_file(fname)
#     612 self.set_size(size)
#     613 self.set_math_fontfamily(math_fontfamily)
#
# File c:\Users\YJ\.conda\envs\django\Lib\site-packages\matplotlib\font_manager.py:856, in FontProperties.set_file(self, file)
#     851 def set_file(self, file):
#     852     """
#     853     Set the filename of the fontfile to use.  In this case, all
#     854     other properties will be ignored.
#     855     """
# --> 856     self._file = os.fspath(file) if file is not None else None
#
# TypeError: expected str, bytes or os.PathLike object, not list

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

#사용하기
fm.fontManager
fig = plt.figure()
axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2)



axes1.hist(x = df['investment'])

plt.tight_layout()
# Out:
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_7620\1803365510.py:17: UserWarning: Glyph 47700 (\N{HANGUL SYLLABLE ME}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_7620\1803365510.py:17: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_7620\1803365510.py:17: UserWarning: Glyph 52768 (\N{HANGUL SYLLABLE CEU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_7620\1803365510.py:17: UserWarning: Glyph 51613 (\N{HANGUL SYLLABLE JEUNG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_7620\1803365510.py:17: UserWarning: Glyph 44428 (\N{HANGUL SYLLABLE GWEON}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_7620\1803365510.py:17: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_7620\1803365510.py:17: UserWarning: Glyph 48372 (\N{HANGUL SYLLABLE BO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_7620\1803365510.py:17: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_7620\1803365510.py:17: UserWarning: Glyph 44397 (\N{HANGUL SYLLABLE GUG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_7620\1803365510.py:17: UserWarning: Glyph 54801 (\N{HANGUL SYLLABLE HYEOB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_7620\1803365510.py:17: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_7620\1803365510.py:17: UserWarning: Glyph 54924 (\N{HANGUL SYLLABLE HOE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_7620\1803365510.py:17: UserWarning: Glyph 53412 (\N{HANGUL SYLLABLE KI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_7620\1803365510.py:17: UserWarning: Glyph 50880 (\N{HANGUL SYLLABLE UM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_7620\1803365510.py:17: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_7620\1803365510.py:17: UserWarning: Glyph 51652 (\N{HANGUL SYLLABLE JIN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_7620\1803365510.py:17: UserWarning: Glyph 53804 (\N{HANGUL SYLLABLE TU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_7620\1803365510.py:17: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 47700 (\N{HANGUL SYLLABLE ME}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 52768 (\N{HANGUL SYLLABLE CEU}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 51613 (\N{HANGUL SYLLABLE JEUNG}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 44428 (\N{HANGUL SYLLABLE GWEON}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 48372 (\N{HANGUL SYLLABLE BO}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 44397 (\N{HANGUL SYLLABLE GUG}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 54801 (\N{HANGUL SYLLABLE HYEOB}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 54924 (\N{HANGUL SYLLABLE HOE}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 53412 (\N{HANGUL SYLLABLE KI}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 50880 (\N{HANGUL SYLLABLE UM}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 51652 (\N{HANGUL SYLLABLE JIN}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 53804 (\N{HANGUL SYLLABLE TU}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47700 (\N{HANGUL SYLLABLE ME}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 52768 (\N{HANGUL SYLLABLE CEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51613 (\N{HANGUL SYLLABLE JEUNG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44428 (\N{HANGUL SYLLABLE GWEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48372 (\N{HANGUL SYLLABLE BO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44397 (\N{HANGUL SYLLABLE GUG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54801 (\N{HANGUL SYLLABLE HYEOB}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54924 (\N{HANGUL SYLLABLE HOE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 53412 (\N{HANGUL SYLLABLE KI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50880 (\N{HANGUL SYLLABLE UM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51652 (\N{HANGUL SYLLABLE JIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 53804 (\N{HANGUL SYLLABLE TU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\YJ\.conda\envs\django\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.
# findfont: Font family 'C:\\Users\\YJ\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Black.ttf' not found.

# %%
print(df['investment'])
# Out:
# 0       메리츠증권
# 1        교보증권
# 2     한국IR협의회
# 3     한국IR협의회
# 4     한국IR협의회
# 5       메리츠증권
# 6     한국IR협의회
# 7     한국IR협의회
# 8       메리츠증권
# 9        SK증권
# 10       LS증권
# 11       SK증권
# 12       키움증권
# 13     유진투자증권
# 14       LS증권
# 15       키움증권
# 16      메리츠증권
# 17       키움증권
# 18       LS증권
# 19       키움증권
# 20    IBK투자증권
# 21     유진투자증권
# 22     유진투자증권
# 23     유진투자증권
# 24       SK증권
# 25       SK증권
# 26       LS증권
# 27       LS증권
# 28       LS증권
# 29      메리츠증권
# Name: investment, dtype: object
